# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
import numpy as np
from scipy import sparse
import joblib
# Out:
# /var/folders/3z/ph1rbqs55v7gpr20vy7k2ht40000gn/T/ipykernel_40862/676881864.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
jazz_df = pd.read_csv('jazz2.csv').fillna('')
meta_df = pd.read_csv('meta.csv').fillna('')

jazz_df = jazz_df.merge(meta_df,on='url')

vectorizer = joblib.load('vectorizer.pkl')
vectors = sparse.load_npz('jazz.npz')
dense_vectors = vectors.todense().tolist()

nbrs = NearestNeighbors(n_neighbors=24,algorithm='brute',radius=2)
nbrs.fit(dense_vectors)

names = np.load('names.npy',allow_pickle=True)

term_df = pd.DataFrame(dense_vectors,columns=names)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator TfidfTransformer from version 1.5.1 when using version 1.5.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator TfidfVectorizer from version 1.5.1 when using version 1.5.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

# %%
def jazz_search(search_string):
    
    distances,indices = nbrs.kneighbors(vectorizer.transform([search_string]))
    mask = distances[0] < 2
    inds = indices[0][mask]

    vecs = pca.fit_transform(vectors[mask])

    points = [{'x': coordinate[0], 'y':coordinate[1]} for coordinate in vecs]

    print(points)
        
    ret_df = jazz_df.iloc[inds][['url','title','image_url','pagetype','genre']]
    
    return {'records': ret_df.to_records().tolist(), 'points':points}

# %%
jazz_search('john coltrane')['records']
# Out:
# [{'x': -0.9507963285345687, 'y': -0.19014411390449107}, {'x': -0.9171410659514696, 'y': -0.03762848048997373}, {'x': -0.12156791196667363, 'y': -0.007581546510239595}, {'x': 0.13846644707754205, 'y': 0.1384382659270665}, {'x': 0.09784192499041998, 'y': 0.0931804198878749}, {'x': 0.0898688227787068, 'y': 0.1634581585894272}, {'x': 0.13158511478974022, 'y': 0.09783947912531543}, {'x': 0.05533838244762222, 'y': 0.014448325629620635}, {'x': 0.18799912361115492, 'y': 0.09628465790000573}, {'x': 0.1253742070266082, 'y': 0.07321050093310934}, {'x': 0.17433389620627737, 'y': 0.08722788942173512}, {'x': 0.18293735836145575, 'y': 0.09750111199489171}, {'x': 0.18308728450398967, 'y': 0.09130121292197262}, {'x': 0.18820532843524176, 'y': 0.10359367272575264}, {'x': 0.21484843559073494, 'y': -0.17177904754481646}, {'x': 0.20025041521286607, 'y': -0.18917517948638185}, {'x': 0.17895318615870967, 'y': 0.09423086394452816}, {'x': 0.17701562596817905, 'y': -0.20756192935864995}, {'x': 0.164306177954942, 'y': 0.11281978244294112}, {'x': 0.12386349484587626, 'y': 0.1090007722842018}, {'x': -0.07028385092285984, 'y': -0.40795145515510317}, {'x': -0.04955797628653955, 'y': -0.42370628056541504}, {'x': -0.5287685660691345, 'y': 0.6563727566895977}, {'x': 0.02384047377117695, 'y': -0.3933798374029697}]
# [(177,
#   'https://en.wikipedia.org/wiki/Ken_Burns_Jazz:_John_Coltrane',
#   'Ken Burns Jazz: John Coltrane',
#   'https://upload.wikimedia.org/wikipedia/en/thumb/5/5e/Ken_Burns_Jazz_John_Coltrane.jpg/220px-Ken_Burns_Jazz_John_Coltrane.jpg',
#   'album',
#   'jazz'),
#  (185,
#   'https://en.wikipedia.org/wiki/First_Meditations_(for_quartet)',
#   'First Meditations (for quartet)',
#   'https://upload.wikimedia.org/wikipedia/en/thumb/4/4a/Coltrane1stMeditationsLP.JPG/220px-Coltrane1stMeditationsLP.JPG',
#   'album',
#   'avant-garde jazz, free jazz, modal jazz'),
#  (195,
#   'https://en.wikipedia.org/wiki/Bye_Bye_Blackbird_(John_Coltrane_album)',
#   'Bye Bye Blackbird (John Coltrane album)',
#   'https://upload.wikimedia.org/wikipedia/en/d/da/Bye_Bye_Blackbird.jpg',
#   'album',
#   'avant-garde jazzmodal jazzhard bop'),
#  (143,
#   'https://en.wikipedia.org/wiki/The_John_Coltrane_Quartet_Plays',
#   'The John Coltrane Quartet Plays',
#   'https://upload.wikimedia.org/wikipedia/en/thumb/6/67/The_John_Coltrane_Quartet_Plays.jpg/220px-The_John_Coltrane_Quartet_Plays.jpg',
#   'album',
#   'post-bop, modal jazz, avant-garde jazz'),
#  (7001,
#   'https://en.wikipedia.org/wiki/John_Coltrane',
#   'John Coltrane',
#   'https://upload.wikimedia.org/wikipedia/commons/thumb/1/14/John_Coltrane_1963_cropped_ver2.jpg/220px-John_Coltrane_1963_cropped_ver2.jpg',
#   'artist',
#   ''),
#  (181,
#   'https://en.wikipedia.org/wiki/Coltrane_(1962_album)',
#   'Coltrane (1962 album)',
#   'https://upload.wikimedia.org/wikipedia/en/thumb/a/a7/Coltrane_Impulse_cover.jpg/220px-Coltrane_Impulse_cover.jpg',
#   'album',
#   'modal jazz'),
#  (179,
#   'https://en.wikipedia.org/wiki/Stellar_Regions',
#   'Stellar Regions',
#   'https://upload.wikimedia.org/wikipedia/en/thumb/2/2e/Stellar_Regions.jpg/220px-Stellar_Regions.jpg',
#   'album',
#   'free jazz'),
#  (167,
#   'https://en.wikipedia.org/wiki/The_Mastery_of_John_Coltrane,_Vol._3:_Jupiter_Variation',
#   'The Mastery of John Coltrane, Vol. 3: Jupiter Variation',
#   'https://upload.wikimedia.org/wikipedia/en/thumb/1/14/The_Mastery_of_John_Coltrane%2C_Vol._III_Jupiter_Variation.JPG/220px-The_Mastery_of_John_Coltrane%2C_Vol._III_Jupiter_Variation.JPG',
#   'album',
#   'free jazz'),
#  (139,
#   'https://en.wikipedia.org/wiki/Om_(John_Coltrane_album)',
#   'Om (John Coltrane album)',
#   'https://upload.wikimedia.org/wikipedia/en/thumb/f/f5/ColtraneOM.jpg/220px-ColtraneOM.jpg',
#   'album',
#   'free jazz, avant-garde jazz'),
#  (130,
#   'https://en.wikipedia.org/wiki/John_Coltrane_and_Johnny_Hartman',
#   'John Coltrane and Johnny Hartman',
#   'https://upload.wikimedia.org/wikipedia/en/thumb/1/12/John_Coltrane_and_Johnny_Hartman_%28album%29.jpg/220px-John_Coltrane_and_Johnny_Hartman_%28album%29.jpg',
#   'album',
#   'jazz'),
#  (170,
#   'https://en.wikipedia.org/wiki/Offering:_Live_at_Temple_University',
#   'Offering: Live at Temple University',
#   'https://upload.wikimedia.org/wikipedia/en/e/e5/John_Coltrane_-_Offering.jpg',
#   'album',
#   'free jazz[1]'),
#  (176,
#   'https://en.wikipedia.org/wiki/The_Paris_Concert_(John_Coltrane_album)',
#   'The Paris Concert (John Coltrane album)',
#   'https://upload.wikimedia.org/wikipedia/en/thumb/3/3e/The_Paris_Concert_%28John_Coltrane_album%29.jpeg/220px-The_Paris_Concert_%28John_Coltrane_album%29.jpeg',
#   'album',
#   ''),
#  (168,
#   'https://en.wikipedia.org/wiki/Standard_Coltrane',
#   'Standard Coltrane',
#   'https://upload.wikimedia.org/wikipedia/en/thumb/2/2a/Standard_Coltrane.jpeg/220px-Standard_Coltrane.jpeg',
#   'album',
#   'jazz (hard bop)'),
#  (173,
#   'https://en.wikipedia.org/wiki/Infinity_(John_Coltrane_album)',
#   'Infinity (John Coltrane album)',
#   'https://upload.wikimedia.org/wikipedia/en/thumb/a/ab/John_Coltrane_Infinity.jpg/220px-John_Coltrane_Infinity.jpg',
#   'album',
#   'jazz'),
#  (194,
#   'https://en.wikipedia.org/wiki/The_Coltrane_Legacy',
#   'The Coltrane Legacy',
#   'https://upload.wikimedia.org/wikipedia/en/thumb/7/79/The_Coltrane_Legacy.jpeg/220px-The_Coltrane_Legacy.jpeg',
#   'album',
#   'jazz'),
#  (156,
#   'https://en.wikipedia.org/wiki/Stardust_(John_Coltrane_album)',
#   'Stardust (John Coltrane album)',
#   'https://upload.wikimedia.org/wikipedia/en/thumb/a/a4/Stardust_%28John_Coltrane_album%29.jpeg/220px-Stardust_%28John_Coltrane_album%29.jpeg',
#   'album',
#   'jazz ballads, hard bop'),
#  (152,
#   'https://en.wikipedia.org/wiki/Bahia_(album)',
#   'Bahia (album)',
#   'https://upload.wikimedia.org/wikipedia/en/thumb/e/ee/TraneBahia.jpg/220px-TraneBahia.jpg',
#   'album',
#   'jazz, hard bop'),
#  (182,
#   'https://en.wikipedia.org/wiki/Gold_Coast_(album)',
#   'Gold Coast (album)',
#   'https://upload.wikimedia.org/wikipedia/en/thumb/2/2b/Gold_Coast_%28album%29.jpeg/220px-Gold_Coast_%28album%29.jpeg',
#   'album',
#   'jazz'),
#  (163,
#   'https://en.wikipedia.org/wiki/Crescent_(John_Coltrane_album)',
#   'Crescent (John Coltrane album)',
#   'https://upload.wikimedia.org/wikipedia/en/thumb/7/7a/John_Coltrane_-_Crescent.jpg/220px-John_Coltrane_-_Crescent.jpg',
#   'album',
#   'avant-garde jazz, post-bop, modal jazz'),
#  (198,
#   'https://en.wikipedia.org/wiki/Live_at_Birdland_(John_Coltrane_album)',
#   'Live at Birdland (John Coltrane album)',
#   'https://upload.wikimedia.org/wikipedia/en/0/0e/Coltrane_Live_at_Birdland.jpg',
#   'album',
#   'jazz, post-bop'),
#  (149,
#   'https://en.wikipedia.org/wiki/Expression_(album)',
#   'Expression (album)',
#   'https://upload.wikimedia.org/wikipedia/en/thumb/2/25/ColtraneExpression.jpg/220px-ColtraneExpression.jpg',
#   'album',
#   'free jazz'),
#  (141,
#   'https://en.wikipedia.org/wiki/Live_in_Seattle_(John_Coltrane_album)',
#   'Live in Seattle (John Coltrane album)',
#   'https://upload.wikimedia.org/wikipedia/en/7/7c/Live_in_Seattle_%28John_Coltrane_album%29.jpg',
#   'album',
#   'free jazz, avant-garde jazz'),
#  (5025,
#   'https://en.wikipedia.org/wiki/Settin%27_the_Pace_(album)',
#   "Settin' the Pace",
#   'https://upload.wikimedia.org/wikipedia/en/thumb/0/0a/John_Coltrane_-_Settin%27_The_Pace.jpg/220px-John_Coltrane_-_Settin%27_The_Pace.jpg',
#   'album',
#   'jazz, hard bop'),
#  (115,
#   'https://en.wikipedia.org/wiki/Cosmic_Music',
#   'Cosmic Music',
#   'https://upload.wikimedia.org/wikipedia/en/c/ce/JohnColtraneCosmicMusicLPCover.JPG',
#   'album',
#   'free jazzavant-garde jazz')]
